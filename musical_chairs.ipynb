# %%
import matplotlib.pyplot as plt
import numpy as np
import collections
import math


from musical_chairs import mc_routine, SecondaryUser

#  UNIVERSE PARAMETERS
n_users = 3
n_arms = 5
t_horizon = 1000
arm_means = [0.2, 0.3, 0.5, 0.8, 0.9]

# ALGORITHM PARAMETERS
params = {
    't0': 40,
    't1': 200,
}

# %%
dummy_r = mc_routine(n_users, params, n_arms, t_horizon, arm_means, plot=True)
# Out:
# top arms 0: [3 4 2]
# top arms 1: [3 0 4]
# top arms 2: [4 3 2]
# selected arm 0: 2
# selected arm 1: 3
# selected arm 2: 2
# top arms 0: [3 4 2]
# top arms 1: [3 4 1]
# top arms 2: [4 3 2]
# selected arm 0: 4
# selected arm 1: 4
# selected arm 2: 4
# top arms 0: [4 3 2]
# top arms 1: [3 4 1]
# top arms 2: [4 1 3]
# selected arm 0: 2
# selected arm 1: -1
# selected arm 2: -1
# top arms 0: [4 3 2]
# top arms 1: [4 3 1]
# top arms 2: [4 1 3]
# selected arm 0: -1
# selected arm 1: -1
# selected arm 2: -1
# top arms 0: [4 3 2]
# top arms 1: [3 4 1]
# top arms 2: [4 1 3]
# selected arm 0: -1
# selected arm 1: -1
# selected arm 2: -1

# %%
print(n_users)
